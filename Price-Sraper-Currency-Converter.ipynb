# %%
pip install requests beautifulsoup4 pandas matplotlib
# Out:
# Requirement already satisfied: requests in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.33.1)
# Requirement already satisfied: beautifulsoup4 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (4.14.3)
# Requirement already satisfied: pandas in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.2)
# Requirement already satisfied: matplotlib in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.10.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests) (2026.2.25)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\grace\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\grace\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\grace\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in C:\Users\grace\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# Scrape Book Data (GBP only)


def scrape_books(url, limit=20):
    books = []

    response = requests.get(url, timeout=10)
    response.raise_for_status()

    soup = BeautifulSoup(response.text, "html.parser")
    items = soup.select("article.product_pod")[:limit]

    for item in items:
        title = item.h3.a["title"]
        price_text = item.select_one(".price_color").text

        price_gbp = float(
            price_text.replace("£", "")
                      .replace("Â", "")
                      .strip()
        )

        books.append({
            "Title": title,
            "Price_GBP": price_gbp
        })

    return books

# %%
# Currency Conversion (Assignment API)

def convert_currency(amount, from_currency, to_currency):
    
    url = "https://api.exchangerate.host/convert"

    params = {
        "access_key": "YOUR_API_KEY",  # Assignment placeholder
        "from": from_currency,
        "to": to_currency,
        "amount": amount
    }

    try:
        response = requests.get(url, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()

        if data.get("success") is True and data.get("result") is not None:
            return data["result"]
        else:
            return None

    except requests.exceptions.RequestException:
        return None

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime



# Scrape Book Data (GBP only)


def scrape_books(url, limit=20):
    books = []

    response = requests.get(url, timeout=10)
    response.raise_for_status()

    soup = BeautifulSoup(response.text, "html.parser")
    items = soup.select("article.product_pod")[:limit]

    for item in items:
        title = item.h3.a["title"]
        price_text = item.select_one(".price_color").text

        price_gbp = float(
            price_text.replace("£", "")
                      .replace("Â", "")
                      .strip()
        )

        books.append({
            "Title": title,
            "Price_GBP": price_gbp
        })

    return books



# Currency Conversion (Assignment API)

def convert_currency(amount, from_currency, to_currency):
    
    url = "https://api.exchangerate.host/convert"

    params = {
        "access_key": "YOUR_API_KEY",  # Assignment placeholder
        "from": from_currency,
        "to": to_currency,
        "amount": amount
    }

    try:
        response = requests.get(url, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()

        if data.get("success") is True and data.get("result") is not None:
            return data["result"]
        else:
            return None

    except requests.exceptions.RequestException:
        return None



# Main Program Logic

SOURCE_URL = "https://books.toscrape.com/"
FROM_CURRENCY = "GBP"
TO_CURRENCY = "KES"
FALLBACK_RATE = 175

# Scrape data
books = scrape_books(SOURCE_URL, limit=20)

# Convert prices
for book in books:
    converted = convert_currency(
        book["Price_GBP"],
        FROM_CURRENCY,
        TO_CURRENCY
    )

    if converted is None:
        book["Price_KES"] = round(book["Price_GBP"] * FALLBACK_RATE, 2)
        book["Conversion_Status"] = "Fallback used (API key required)"
    else:
        book["Price_KES"] = round(converted, 2)
        book["Conversion_Status"] = "Live API conversion"

# Create DataFrame
df = pd.DataFrame(books)
df["Conversion_Time"] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# Display results
print("\nScraped & Converted Prices:")
print(df.to_string(index=False))

# Save output files
df.to_csv("book_prices_converted.csv", index=False)
df.to_json("book_prices_converted.json", orient="records", indent=4)


# Plot

df.plot(
    x="Title",
    y="Price_GBP",
    kind="bar",
    figsize=(12, 6),
    title="Book Prices in GBP"
)

plt.ylabel("Price (GBP)")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

df.plot(
    x="Title",
    y="Price_KES",
    kind="bar",
    figsize=(12, 6),
    title="Book Prices in KES"
)

plt.ylabel("Price (KES)")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# Scraped & Converted Prices:
#                                                                                          Title  Price_GBP  Price_KES                Conversion_Status     Conversion_Time
#                                                                           A Light in the Attic      51.77    9059.75 Fallback used (API key required) 2026-04-15 08:17:16
#                                                                             Tipping the Velvet      53.74    9404.50 Fallback used (API key required) 2026-04-15 08:17:16
#                                                                                     Soumission      50.10    8767.50 Fallback used (API key required) 2026-04-15 08:17:16
#                                                                                  Sharp Objects      47.82    8368.50 Fallback used (API key required) 2026-04-15 08:17:16
#                                                          Sapiens: A Brief History of Humankind      54.23    9490.25 Fallback used (API key required) 2026-04-15 08:17:16
#                                                                                The Requiem Red      22.65    3963.75 Fallback used (API key required) 2026-04-15 08:17:16
#                                             The Dirty Little Secrets of Getting Your Dream Job      33.34    5834.50 Fallback used (API key required) 2026-04-15 08:17:16
#        The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull      17.93    3137.75 Fallback used (API key required) 2026-04-15 08:17:16
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics      22.60    3955.00 Fallback used (API key required) 2026-04-15 08:17:16
#                                                                                The Black Maria      52.15    9126.25 Fallback used (API key required) 2026-04-15 08:17:16
#                                                 Starving Hearts (Triangular Trade Trilogy, #1)      13.99    2448.25 Fallback used (API key required) 2026-04-15 08:17:16
#                                                                          Shakespeare's Sonnets      20.66    3615.50 Fallback used (API key required) 2026-04-15 08:17:16
#                                                                                    Set Me Free      17.46    3055.50 Fallback used (API key required) 2026-04-15 08:17:16
#                                        Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)      52.29    9150.75 Fallback used (API key required) 2026-04-15 08:17:16
#                                                                      Rip it Up and Start Again      35.02    6128.50 Fallback used (API key required) 2026-04-15 08:17:16
#             Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991      57.25   10018.75 Fallback used (API key required) 2026-04-15 08:17:16
#                                                                                           Olio      23.88    4179.00 Fallback used (API key required) 2026-04-15 08:17:16
#                                          Mesaerion: The Best Science Fiction Stories 1800-1849      37.59    6578.25 Fallback used (API key required) 2026-04-15 08:17:16
#                                                                   Libertarianism for Beginners      51.33    8982.75 Fallback used (API key required) 2026-04-15 08:17:16
#                                                                        It's Only the Himalayas      45.17    7904.75 Fallback used (API key required) 2026-04-15 08:17:16
